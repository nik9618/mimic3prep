# %%
# DB connection:
import psycopg2
import datetime
import sys
from operator import itemgetter, attrgetter, methodcaller
import numpy as np
import itertools
import os.path
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
try:
    conn = psycopg2.connect("dbname='mimic' user='mimic' host='localhost' password='meladymimic315'")
except:
    print "I am unable to connect to the database"
print 'connection established'
# Out:
# connection established

# %%
_adm = np.load('res/admission_ids.npy').tolist()
admission_ids = _adm['admission_ids']
admission_ids_txt = _adm['admission_ids_txt']

db = np.load('res/itemids.npy').tolist()
input_itemid = db['input']
output_itemid = db['output']
chart_itemid = db['chart']
lab_itemid = db['lab']
microbio_itemid = db['microbio']
prescript_itemid = db['prescript']

# %%
valid_chart = []
valid_chart_unit = []
valid_chart_cate = []
dropped = []

# %%
# chartevents
for i in chart_itemid:
    cur = conn.cursor()
    cur.execute('SELECT valueuom, count(valueuom) FROM mimiciii.chartevents WHERE itemid = '+ str(i) +' and hadm_id in ('+admission_ids_txt+') group by valueuom')
    chartunits = cur.fetchall()
    chartunits = sorted(chartunits, key=lambda tup: tup[1])
    chartunits.reverse()

    total = 0
    for c in chartunits:
        total += c[1]
    if(total == 0 ): continue;
    percentage = float(chartunits[0][1]) / total * 100.
    
    cur = conn.cursor()
    cur.execute('SELECT label FROM mimiciii.d_items WHERE itemid = '+ str(i))
    label = cur.fetchone()
    
    print label[0]
    print "CHART "+str(i) + " : " + "{:.2f}".format(percentage)
    print "UNITS : "+ str(chartunits) + "({:d})".format(len(chartunits))
    
    cur = conn.cursor()
    cur.execute('SELECT count(*) FROM mimiciii.chartevents WHERE itemid = '+ str(i) +' and hadm_id in ('+admission_ids_txt+') and valuenum is null')
    notnum = cur.fetchone()
    
    cur = conn.cursor()
    cur.execute('SELECT count(*) FROM mimiciii.chartevents WHERE itemid = '+ str(i) +' and hadm_id in ('+admission_ids_txt+')')
    total = cur.fetchone()
    
    cur = conn.cursor()
    cur.execute('SELECT value,valuenum FROM mimiciii.chartevents WHERE itemid = '+ str(i) +' and hadm_id in ('+admission_ids_txt+') limit 20')
    samples = cur.fetchall()
    ss = []
    for j in samples: ss.append(j)
    
    percentage =float(total[0] -notnum[0])*100 / total[0]
    print "Numeric observation :" + "{:.4f}%".format(percentage)+ " ( NOTNUM= " + str(notnum[0]) + " / ALL= " + str(total[0]) + " ) "
    if(percentage < 80): 
        print 'dropped\n'
        dropped.append(i)
        continue;
    print ''
    
    valid_chart.append(i);
    valid_chart_unit.append(chartunits[0][0]);
# Out:
# Stool Guaiac QC
# CHART 227801 : 100.00
# UNITS : [('', 7071L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7071 )
#
# WBCScore_ApacheIV
# CHART 227063 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Cardiac Output (CO NICOM)
# CHART 228369 : 100.00
# UNITS : [('L/min', 715L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 715 )
#
# Presep Catheter Dressing Occlusive
# CHART 227419 : 100.00
# UNITS : [('', 456L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 456 )
#
# ICU Consent Signed
# CHART 226185 : 100.00
# UNITS : [('', 5664L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 5664 )
#
# Sheath Zero/Calibrate
# CHART 225771 : 100.00
# UNITS : [('', 519L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 519 )
#
# PCA attempt
# CHART 224663 : 100.00
# UNITS : [('', 18966L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 18966 )
#
# Cholesterol
# CHART 220603 : 100.00
# UNITS : [('mg/dL', 1402L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1402 )
#
# ICP Line Zero/Calibrate
# CHART 226134 : 100.00
# UNITS : [('', 2801L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2801 )
#
# Diabetes
# CHART 227007 : 100.00
# UNITS : [('', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# Orthostatic BPd lying
# CHART 226092 : 100.00
# UNITS : [('mmHg', 165L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 165 )
#
# Dialysis patient
# CHART 225126 : 100.00
# UNITS : [('', 33566L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 33566 )
#
# Ionized Calcium
# CHART 225667 : 99.85
# UNITS : [('mmol/L', 70892L), ('', 108L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 71000 )
#
# Impaired Skin Depth #10
# CHART 227597 : 100.00
# UNITS : [('cm', 284L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 284 )
#
# Glucose (serum)
# CHART 220621 : 95.85
# UNITS : [('mg/dL', 136054L), ('', 5898L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 141952 )
#
# Vital Cap
# CHART 224420 : 100.00
# UNITS : [('Liters', 541L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 541 )
#
# Baseline Current/mA
# CHART 224661 : 100.00
# UNITS : [('mA', 6842L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6842 )
#
# Tobramycin (Trough)
# CHART 227452 : 100.00
# UNITS : [('ug/mL', 189L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 189 )
#
# Peak Exp Flow Rate
# CHART 224728 : 100.00
# UNITS : [('L/min', 118L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 118 )
#
# 14 Gauge placed in outside facility
# CHART 226135 : 100.00
# UNITS : [('', 3027L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3027 )
#
# AgeApacheIIScore
# CHART 226738 : 100.00
# UNITS : [('', 11L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 11 )
#
# TFCd0 (NICOM)
# CHART 228379 : 100.00
# UNITS : [('%', 44L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 44 )
#
# See chart for initial patient assessment
# CHART 225175 : 100.00
# UNITS : [('', 14581L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 14581 )
#
# Heart rate Alarm - High
# CHART 220046 : 100.00
# UNITS : [('bpm', 209259L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 209259 )
#
# Temporary Pacemaker Wires Ground
# CHART 223963 : 100.00
# UNITS : [('', 2625L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2625 )
#
# Plateau Pressure
# CHART 224696 : 100.00
# UNITS : [('cmH2O', 74283L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 74283 )
#
# Difficulty swallowing
# CHART 225118 : 100.00
# UNITS : [('', 35105L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 35105 )
#
# In-line Suction Catheter Changed
# CHART 227807 : 100.00
# UNITS : [('', 494L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 494 )
#
# PAEDP
# CHART 224654 : 100.00
# UNITS : [('mmHg', 8310L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8310 )
#
# T Low (APRV)
# CHART 224709 : 100.00
# UNITS : [('sec', 911L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 911 )
#
# PhApacheIIScore
# CHART 226768 : 100.00
# UNITS : [('', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Orthostatic BPd sitting
# CHART 226094 : 100.00
# UNITS : [('mmHg', 192L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 192 )
#
# 16 Gauge Dressing Occlusive
# CHART 227366 : 100.00
# UNITS : [('', 36323L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 36323 )
#
# Total Bilirubin
# CHART 225690 : 99.97
# UNITS : [('mg/dL', 34973L), ('', 11L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 34984 )
#
# Respiratory Rate (Set)
# CHART 224688 : 100.00
# UNITS : [('insp/min', 217322L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 217322 )
#
# Manual Blood Pressure Systolic Left
# CHART 224167 : 100.00
# UNITS : [('mmHg', 737L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 737 )
#
# Specific Gravity (urine)
# CHART 227471 : 100.00
# UNITS : [('', 15597L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 15597 )
#
# Tandem Heart Access Line Dressing Occlusive
# CHART 228208 : 100.00
# UNITS : [('', 119L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 119 )
#
# Inspired O2 Fraction
# CHART 223835 : 100.00
# UNITS : [('', 554039L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 554039 )
#
# Impaired Skin Depth #4
# CHART 224897 : 100.00
# UNITS : [('cm', 4206L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 4206 )
#
# PICC Line Tip Cultured
# CHART 225732 : 100.00
# UNITS : [('', 1777L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1777 )
#
# Rest RR - Aerobic Activity Response
# CHART 227918 : 100.00
# UNITS : [('', 152L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 152 )
#
# Intra Cranial Pressure #2 Alarm - High
# CHART 227990 : 100.00
# UNITS : [('mmHg', 120L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 120 )
#
# Thrombolytic therapy
# CHART 227056 : 100.00
# UNITS : [('', 2L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2 )
#
# ICP Line Dressing Occlusive
# CHART 227363 : 100.00
# UNITS : [('', 8778L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8778 )
#
# Tunneled (Hickman) placed in outside facility
# CHART 226121 : 100.00
# UNITS : [('', 2490L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2490 )
#
# ALT
# CHART 220644 : 99.97
# UNITS : [('IU/L', 34650L), ('', 11L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 34661 )
#
# Cordis/Introducer Line Tip Cultured
# CHART 225724 : 100.00
# UNITS : [('', 1301L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1301 )
#
# Manual Blood Pressure Diastolic Left
# CHART 224643 : 100.00
# UNITS : [('mmHg', 668L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 668 )
#
# Currently experiencing pain
# CHART 225113 : 100.00
# UNITS : [('', 33271L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 33271 )
#
# Cough/Deep Breath
# CHART 225188 : 100.00
# UNITS : [('', 76160L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 76160 )
#
# Bilirubin_ApacheIV
# CHART 226998 : 100.00
# UNITS : [('', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# PHApacheIIValue
# CHART 226769 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Subglottal Suctioning
# CHART 226169 : 100.00
# UNITS : [('', 127675L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 127675 )
#
# Recovery O2 sat - Aerobic Activity Response
# CHART 227933 : 100.00
# UNITS : [('%', 110L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 110 )
#
# Assisted Systole
# CHART 224309 : 100.00
# UNITS : [('mmHg', 8491L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8491 )
#
# Unable to assess teaching / learning needs
# CHART 225129 : 100.00
# UNITS : [('', 16044L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 16044 )
#
# 20 Gauge placed in outside facility
# CHART 226138 : 100.00
# UNITS : [('', 176225L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 176225 )
#
# GCS - Eye Opening
# CHART 220739 : 100.00
# UNITS : [('', 564369L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 564369 )
#
# Intubated_ApacheIV
# CHART 227021 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Recreational drug use
# CHART 225110 : 100.00
# UNITS : [('', 31700L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 31700 )
#
# Rest HR - Aerobic Capacity
# CHART 227858 : 100.00
# UNITS : [('', 369L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 369 )
#
# Tandem Heart Return Cannula Migration
# CHART 228222 : 100.00
# UNITS : [('', 109L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 109 )
#
# Calibrated (PiCCO)
# CHART 228175 : 100.00
# UNITS : [('', 377L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 377 )
#
# Venous O2 Pressure
# CHART 226063 : 100.00
# UNITS : [('mmHg', 4105L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 4105 )
#
# PCWP
# CHART 223771 : 100.00
# UNITS : [('mmHg', 590L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 590 )
#
# Hemoglobin
# CHART 220228 : 100.00
# UNITS : [('g/dl', 124849L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 124849 )
#
# O2 saturation pulseoxymetry
# CHART 220277 : 100.00
# UNITS : [('%', 2642440L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2642440 )
#
# Impaired Skin Odor #9
# CHART 227604 : 100.00
# UNITS : [('', 2355L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2355 )
#
# Low risk (25-50) interventions
# CHART 227348 : 100.00
# UNITS : [('', 713L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 713 )
#
# O2 Flow (additional cannula)
# CHART 227287 : 100.00
# UNITS : [('L/min', 19145L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 19145 )
#
# Gentamicin (Trough)
# CHART 227449 : 99.06
# UNITS : [('ug/mL', 210L), ('', 2L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 212 )
#
# Small Volume Neb Dose #2
# CHART 224178 : 100.00
# UNITS : [('', 378L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 378 )
#
# Left Ventricular Assit Device Flow
# CHART 220125 : 100.00
# UNITS : [('L/min', 24L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 24 )
#
# ELWI (PiCCO)
# CHART 228179 : 100.00
# UNITS : [('ml/kg', 1184L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1184 )
#
# VA hospital
# CHART 225418 : 100.00
# UNITS : [('', 11L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 11 )
#
# Central Venous Pressure Alarm - High
# CHART 220072 : 100.00
# UNITS : [('mmHg', 36214L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 36214 )
#
# PA Catheter Dressing Occlusive
# CHART 227351 : 100.00
# UNITS : [('', 11402L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 11402 )
#
# Height
# CHART 226707 : 100.00
# UNITS : [('Inch', 11755L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 11755 )
#
# SVV (PiCCO)
# CHART 228184 : 100.00
# UNITS : [('%', 1366L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1366 )
#
# Arterial Blood Pressure diastolic
# CHART 220051 : 100.00
# UNITS : [('mmHg', 1138847L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1138847 )
#
# Ammonia
# CHART 220580 : 99.84
# UNITS : [('umol/L', 633L), ('', 1L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 634 )
#
# Height (cm)
# CHART 226730 : 100.00
# UNITS : [('cm', 11755L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 11755 )
#
# Orthostatic BPs standing
# CHART 223766 : 100.00
# UNITS : [('mmHg', 136L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 136 )
#
# Unable to assess cognitive / perceptual
# CHART 225086 : 100.00
# UNITS : [('', 14967L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 14967 )
#
# Non Invasive Blood Pressure systolic
# CHART 220179 : 100.00
# UNITS : [('mmHg', 1271944L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1271944 )
#
# Activity O2 Sat - Aerobic Capacity
# CHART 227867 : 100.00
# UNITS : [('%', 264L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 264 )
#
# ATC %
# CHART 224704 : 100.00
# UNITS : [('%', 368L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 368 )
#
# Glucose (whole blood)
# CHART 226537 : 71.69
# UNITS : [('mg/dL', 46063L), ('', 18194L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 64257 )
#
# Temporary Atrial Sens Setting mV
# CHART 224753 : 100.00
# UNITS : [('mV', 10051L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10051 )
#
# Rest HR -  Aerobic Activity Response
# CHART 227916 : 100.00
# UNITS : [('', 177L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 177 )
#
# O2 Consumption
# CHART 224726 : 100.00
# UNITS : [('ml/min', 1L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1 )
#
# HematocritApacheIIScore
# CHART 226761 : 100.00
# UNITS : [('', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# SVI Change
# CHART 228377 : 100.00
# UNITS : [('%', 113L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 113 )
#
# Tobacco use
# CHART 225108 : 100.00
# UNITS : [('', 658L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 658 )
#
# VAD Beat Rate L
# CHART 224363 : 100.00
# UNITS : [('bpm', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# FK506
# CHART 227462 : 100.00
# UNITS : [('ng/mL', 2095L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2095 )
#
# Clot Size (cm)
# CHART 227647 : 100.00
# UNITS : [('cm', 43L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 43 )
#
# ECMO
# CHART 224660 : 100.00
# UNITS : [('L/min', 213L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 213 )
#
# Non Invasive Blood Pressure diastolic
# CHART 220180 : 100.00
# UNITS : [('mmHg', 1271355L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1271355 )
#
# BiPap IPAP
# CHART 227580 : 100.00
# UNITS : [('cmH2O', 1580L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1580 )
#
# Pregnant
# CHART 225082 : 100.00
# UNITS : [('', 7839L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7839 )
#
# Temperature Celsius
# CHART 223762 : 100.00
# UNITS : [('?C', 73813L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 73813 )
#
# GcsScore_ApacheIV
# CHART 227013 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Recruitment Press
# CHART 224710 : 100.00
# UNITS : [('cmH2O', 336L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 336 )
#
# CHG Bath
# CHART 228137 : 100.00
# UNITS : [('', 17394L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 17394 )
#
# Activity HR - Aerobic Activity Response
# CHART 227923 : 100.00
# UNITS : [('', 116L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 116 )
#
# Permanent Pacemaker Rate
# CHART 224845 : 100.00
# UNITS : [('/min', 2665L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2665 )
#
# Infusate Drops/Minute
# CHART 228190 : 100.00
# UNITS : [('', 648L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 648 )
#
# Tobramycin (Peak)
# CHART 227450 : 100.00
# UNITS : [('ug/mL', 67L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 67 )
#
# Arterial Blood Pressure Alarm - High
# CHART 220058 : 100.00
# UNITS : [('mmHg', 83712L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 83712 )
#
# Arctic Sun/Alsius Temp #2 C
# CHART 227634 : 100.00
# UNITS : [('?C', 9697L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9697 )
#
# EF (CCO)
# CHART 226272 : 100.00
# UNITS : [('%', 307L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 307 )
#
# Post menopausal
# CHART 225085 : 100.00
# UNITS : [('', 7977L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7977 )
#
# WBC
# CHART 220546 : 99.93
# UNITS : [('K/uL', 121055L), ('', 86L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 121141 )
#
# IABP Zero/Calibrate
# CHART 225342 : 100.00
# UNITS : [('', 2037L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2037 )
#
# Temporary Ventricular Stim Setting mA
# CHART 224838 : 100.00
# UNITS : [('mA', 6244L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6244 )
#
# Impaired Skin Length #5
# CHART 224919 : 100.00
# UNITS : [('cm', 8797L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8797 )
#
# TCO2 (calc) Venous
# CHART 223679 : 99.17
# UNITS : [('mEq/L', 4074L), ('', 34L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 4108 )
#
# HrScore_ApacheIV
# CHART 227019 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# D-Dimer
# CHART 225636 : 99.85
# UNITS : [('ng/mL', 680L), ('', 1L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 681 )
#
# Impaired Skin Depth #5
# CHART 224898 : 100.00
# UNITS : [('cm', 2468L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2468 )
#
# Vancomycin (Random)
# CHART 227454 : 99.87
# UNITS : [('ug/mL', 6012L), ('', 8L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6020 )
#
# Cardiac Index (CI NICOM)
# CHART 228368 : 100.00
# UNITS : [('L/min/m2', 880L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 880 )
#
# Impaired Skin Length #8
# CHART 224922 : 100.00
# UNITS : [('cm', 2414L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2414 )
#
# Impaired Skin Length #1
# CHART 224562 : 100.00
# UNITS : [('cm', 52222L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 52222 )
#
# Pulmonary Artery Pressure mean
# CHART 220061 : 100.00
# UNITS : [('mmHg', 125639L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 125639 )
#
# Troponin-T
# CHART 227429 : 99.92
# UNITS : [('ng/mL', 21203L), ('', 18L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 21221 )
#
# Pinsp (Draeger only)
# CHART 227187 : 100.00
# UNITS : [('cmH2O', 7045L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7045 )
#
# HCO3ApacheIIValue
# CHART 226759 : 100.00
# UNITS : [('', 8L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8 )
#
# Recovery HR - Aerobic Activity Response
# CHART 227930 : 100.00
# UNITS : [('', 114L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 114 )
#
# Thrombin
# CHART 227469 : 100.00
# UNITS : [('sec', 102L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 102 )
#
# ABI Ankle BP R
# CHART 224317 : 100.00
# UNITS : [('mmHg', 30L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 30 )
#
# Purge Pressure
# CHART 228158 : 100.00
# UNITS : [('mmHg', 29L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 29 )
#
# Skeletal Traction #2 - Pounds
# CHART 227776 : 100.00
# UNITS : [('lbs', 136L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 136 )
#
# Impaired Skin Width #1
# CHART 224846 : 100.00
# UNITS : [('cm', 50145L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 50145 )
#
# PCA bolus
# CHART 224410 : 100.00
# UNITS : [('', 3414L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3414 )
#
# Impella Dressing Occlusive
# CHART 228167 : 100.00
# UNITS : [('', 4L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 4 )
#
# Filter Pressure
# CHART 224150 : 100.00
# UNITS : [('mmHg', 57782L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 57782 )
#
# DswfApacheScore
# CHART 226753 : 100.00
# UNITS : [('', 9L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9 )
#
# WBCApacheIIValue
# CHART 226780 : 100.00
# UNITS : [('', 9L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9 )
#
# Temporary Atrial Sens Threshold mV
# CHART 224752 : 100.00
# UNITS : [('mV', 8486L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8486 )
#
# Sodium_ApacheIV
# CHART 227052 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Social work consult
# CHART 225078 : 100.00
# UNITS : [('', 29876L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 29876 )
#
# Total PEEP Level
# CHART 224700 : 100.00
# UNITS : [('cmH2O', 44125L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 44125 )
#
# Cortisol
# CHART 227463 : 99.77
# UNITS : [('ug/dL', 2574L), ('', 6L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2580 )
#
# Impaired Skin Odor #2
# CHART 224923 : 100.00
# UNITS : [('', 72047L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 72047 )
#
# CCO PAC placed in outside facility
# CHART 226108 : 100.00
# UNITS : [('', 7765L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7765 )
#
# Prothrombin time
# CHART 227465 : 99.94
# UNITS : [('sec', 84215L), ('', 54L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 84269 )
#
# Cash amount
# CHART 225209 : 100.00
# UNITS : [('', 3684L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3684 )
#
# Cardiac Output (thermodilution)
# CHART 220088 : 100.00
# UNITS : [('L/min', 9538L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9538 )
#
# BiPap EPAP
# CHART 227579 : 100.00
# UNITS : [('cmH2O', 1854L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1854 )
#
# ART BP Systolic
# CHART 225309 : 100.00
# UNITS : [('mmHg', 86486L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 86486 )
#
# Amylase
# CHART 220581 : 99.95
# UNITS : [('IU/L', 7293L), ('', 4L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7297 )
#
# ST Segment Monitoring On
# CHART 228305 : 100.00
# UNITS : [('', 104325L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 104325 )
#
# BunScore_ApacheIV
# CHART 227001 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Tandem Heart Flow
# CHART 228198 : 100.00
# UNITS : [('L/min', 688L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 688 )
#
# Temporary Pacemaker Wires Venticular
# CHART 223962 : 100.00
# UNITS : [('', 25498L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 25498 )
#
# Impaired Skin Depth #3
# CHART 224896 : 100.00
# UNITS : [('cm', 6300L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6300 )
#
# High risk (>51) interventions
# CHART 227349 : 100.00
# UNITS : [('', 90334L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 90334 )
#
# Procan
# CHART 227458 : 100.00
# UNITS : [('ug/mL', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Arterial CO2 Pressure
# CHART 220235 : 100.00
# UNITS : [('mmHg', 124061L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 124061 )
#
# Medication Bolus - Adjunctive Pain Management
# CHART 227813 : 100.00
# UNITS : [('', 164L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 164 )
#
# Total Granulocyte Count (TGC)
# CHART 225692 : 100.00
# UNITS : [('#/uL', 553L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 553 )
#
# Albumin_ApacheIV
# CHART 226981 : 100.00
# UNITS : [('', 4L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 4 )
#
# Temporary Pacemaker Rate
# CHART 224751 : 100.00
# UNITS : [('bpm', 24924L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 24924 )
#
# AaDO2ApacheIIValue
# CHART 226737 : 100.00
# UNITS : [('mmHg', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Money given to hospital cashier
# CHART 225142 : 100.00
# UNITS : [('', 420L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 420 )
#
# OxygenApacheIIScore
# CHART 226767 : 100.00
# UNITS : [('', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Urine output_ApacheIV
# CHART 227519 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# AVA Dressing Occlusive
# CHART 227723 : 100.00
# UNITS : [('', 3389L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3389 )
#
# Admission Weight (Kg)
# CHART 226512 : 100.00
# UNITS : [('kg', 22253L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 22253 )
#
# Impaired Skin Length #9
# CHART 227602 : 100.00
# UNITS : [('cm', 1367L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1367 )
#
# MDI #2 Puff
# CHART 224172 : 100.00
# UNITS : [('', 20969L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 20969 )
#
# Unintentional weight loss >10 lbs.
# CHART 225124 : 100.00
# UNITS : [('', 29152L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 29152 )
#
# ChpApacheIIScore
# CHART 226749 : 100.00
# UNITS : [('', 9L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9 )
#
# PCV Level (Avea)
# CHART 224702 : 100.00
# UNITS : [('cmH2O', 460L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 460 )
#
# Use A-aDO2
# CHART 227060 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# BiPap bpm (S/T -Back up)
# CHART 227581 : 100.00
# UNITS : [('bpm', 138L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 138 )
#
# SodiumScore_ApacheIV
# CHART 227053 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Oxygenator/ECMO
# CHART 228193 : 100.00
# UNITS : [('', 680L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 680 )
#
# HrApacheIIValue
# CHART 226764 : 100.00
# UNITS : [('bpm', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Intra Cranial Pressure
# CHART 220765 : 100.00
# UNITS : [('mmHg', 92301L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 92301 )
#
# O2 Flow
# CHART 223834 : 100.00
# UNITS : [('L/min', 199784L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 199784 )
#
# Vd/Vt Ratio
# CHART 224743 : 100.00
# UNITS : [('', 46L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 46 )
#
# Arterial Blood Pressure Alarm - Low
# CHART 220056 : 100.00
# UNITS : [('mmHg', 83782L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 83782 )
#
# CO / CI Change
# CHART 228370 : 100.00
# UNITS : [('%', 108L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 108 )
#
# TCO2 (calc) Arterial
# CHART 225698 : 99.80
# UNITS : [('mEq/L', 123777L), ('', 250L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 124027 )
#
# Skeletal Traction #1 - Pounds
# CHART 227775 : 100.00
# UNITS : [('lbs', 508L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 508 )
#
# Differential-Basos
# CHART 225639 : 99.97
# UNITS : [('%', 18936L), ('', 6L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 18942 )
#
# ART Blood Pressure Alarm - High
# CHART 227537 : 100.00
# UNITS : [('mmHg', 5011L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 5011 )
#
# CO (PiCCO)
# CHART 228178 : 100.00
# UNITS : [('L/min', 1979L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1979 )
#
# PICC Line Dressing Occlusive
# CHART 227358 : 100.00
# UNITS : [('', 83274L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 83274 )
#
# Dialysis Catheter placed in outside facility
# CHART 226118 : 100.00
# UNITS : [('', 31429L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 31429 )
#
# Re-admit < 48 hours
# CHART 226892 : 100.00
# UNITS : [('', 168L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 168 )
#
# Ventilated at any time during ICU Day 1
# CHART 227061 : 100.00
# UNITS : [('', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# TFCd (NICOM)
# CHART 228378 : 100.00
# UNITS : [('%', 36L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 36 )
#
# History of slips / falls
# CHART 225094 : 100.00
# UNITS : [('', 40034L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 40034 )
#
# Alkaline Phosphate
# CHART 225612 : 99.97
# UNITS : [('IU/L', 33936L), ('', 10L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 33946 )
#
# Impaired Skin Width #6
# CHART 224955 : 100.00
# UNITS : [('cm', 5529L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 5529 )
#
# Sodium (whole blood)
# CHART 226534 : 99.24
# UNITS : [('mEq/L', 14716L), ('', 112L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 14828 )
#
# MapApacheIIValue
# CHART 226766 : 100.00
# UNITS : [('mmHg', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Trach Care
# CHART 227130 : 100.00
# UNITS : [('', 16073L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 16073 )
#
# BUN
# CHART 225624 : 99.93
# UNITS : [('mg/dL', 138808L), ('', 97L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 138905 )
#
# Multi Lumen Dressing Occlusive
# CHART 227293 : 100.00
# UNITS : [('', 142155L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 142155 )
#
# CO-Tandem Heart Flow
# CHART 228189 : 100.00
# UNITS : [('L/min', 15L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 15 )
#
# Arterial Blood Pressure mean
# CHART 220052 : 100.00
# UNITS : [('mmHg', 1145467L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1145467 )
#
# PTT
# CHART 227466 : 99.91
# UNITS : [('sec', 90098L), ('', 81L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 90179 )
#
# APACHE II Predecited Death Rate
# CHART 226745 : 100.00
# UNITS : [('%', 11L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 11 )
#
# HematocritApacheIIValue
# CHART 226762 : 100.00
# UNITS : [('', 9L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9 )
#
# Total Peripheral Resistance (TPR) (NICOM)
# CHART 228381 : 100.00
# UNITS : [('dynes*sec/cm5', 134L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 134 )
#
# Paw High
# CHART 223873 : 100.00
# UNITS : [('cmH2O', 452296L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 452296 )
#
# BUN_ApacheIV
# CHART 227000 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Cuff Pressure
# CHART 224417 : 100.00
# UNITS : [('cmH2O', 40416L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 40416 )
#
# Alarms On
# CHART 224641 : 100.00
# UNITS : [('', 510226L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 510226 )
#
# Vibration in Line
# CHART 228200 : 100.00
# UNITS : [('', 529L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 529 )
#
# Trauma Line Dressing Occlusive
# CHART 227353 : 100.00
# UNITS : [('', 3933L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3933 )
#
# 18 Gauge placed in outside facility
# CHART 226137 : 100.00
# UNITS : [('', 129666L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 129666 )
#
# Chronic Dilaysis
# CHART 226750 : 100.00
# UNITS : [('', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# Nitric Oxide
# CHART 224749 : 100.00
# UNITS : [('ppm', 430L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 430 )
#
# Midline Dressing Occlusive
# CHART 227418 : 100.00
# UNITS : [('', 6637L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6637 )
#
# MDI #3 Puff
# CHART 224175 : 100.00
# UNITS : [('', 968L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 968 )
#
# Triple Introducer Dressing Occlusive
# CHART 227354 : 100.00
# UNITS : [('', 517L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 517 )
#
# AST
# CHART 220587 : 99.97
# UNITS : [('IU/L', 34630L), ('', 10L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 34640 )
#
# 14 Gauge placed in the field
# CHART 228097 : 100.00
# UNITS : [('', 1507L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1507 )
#
# CreatinineApacheIIValue
# CHART 226752 : 100.00
# UNITS : [('', 8L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8 )
#
# FiO2_ApacheIV
# CHART 227010 : 100.00
# UNITS : [('%', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# Chloride (serum)
# CHART 220602 : 99.92
# UNITS : [('mEq/L', 147132L), ('', 124L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 147256 )
#
# SodiumApacheIIValue
# CHART 226776 : 100.00
# UNITS : [('', 9L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9 )
#
# Midline placed in outside facility
# CHART 226112 : 100.00
# UNITS : [('', 6130L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6130 )
#
# Impaired Skin Depth #7
# CHART 224900 : 100.00
# UNITS : [('cm', 849L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 849 )
#
# Non-Invasive Blood Pressure Alarm - High
# CHART 223751 : 100.00
# UNITS : [('mmHg', 150461L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 150461 )
#
# MapApacheIIScore
# CHART 226765 : 100.00
# UNITS : [('', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# PCA total dose
# CHART 224665 : 100.00
# UNITS : [('', 13890L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 13890 )
#
# ABI Brachial BP L
# CHART 224315 : 100.00
# UNITS : [('mmHg', 30L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 30 )
#
# Resp Alarm - Low
# CHART 224162 : 100.00
# UNITS : [('insp/min', 204915L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 204915 )
#
# Is the spokesperson the Health Care Proxy
# CHART 225067 : 100.00
# UNITS : [('', 32765L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 32765 )
#
# Transportation
# CHART 225422 : 100.00
# UNITS : [('', 20L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 20 )
#
# PO2 (Mixed Venous)
# CHART 227516 : 100.00
# UNITS : [('mmHg', 2304L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2304 )
#
# Presep Catheter Zero/Calibrate
# CHART 225389 : 100.00
# UNITS : [('', 797L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 797 )
#
# Arterial Base Excess
# CHART 224828 : 99.78
# UNITS : [('mEq/L', 123770L), ('', 274L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 124044 )
#
# Cordis/Introducer placed in outside facility
# CHART 226109 : 100.00
# UNITS : [('', 24764L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 24764 )
#
# IABP Dressing Occlusive
# CHART 227355 : 100.00
# UNITS : [('', 2060L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2060 )
#
# Return Pressure
# CHART 224152 : 100.00
# UNITS : [('mmHg', 57678L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 57678 )
#
# PH (Venous)
# CHART 220274 : 99.36
# UNITS : [('units', 8042L), ('', 52L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8094 )
#
# Code Status
# CHART 223758 : 100.00
# UNITS : [('', 89968L)](1)
# Numeric observation :0.0000% ( NOTNUM= 89968 / ALL= 89968 )
# droped
#
# Pericardial Drain Flush
# CHART 225990 : 100.00
# UNITS : [('', 337L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 337 )
#
# IABP Alarms Activated
# CHART 225981 : 100.00
# UNITS : [('', 2015L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2015 )
#
# SvO2
# CHART 223772 : 100.00
# UNITS : [('%', 60968L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 60968 )
#
# Creatinine_ApacheIV
# CHART 227005 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Alsius Bath Temp
# CHART 228392 : 100.00
# UNITS : [('?C', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# Impaired Skin Odor #6
# CHART 224927 : 100.00
# UNITS : [('', 11113L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 11113 )
#
# Tandem Heart Access Line Repositioned
# CHART 228213 : 100.00
# UNITS : [('', 92L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 92 )
#
# Inspiratory Time
# CHART 224738 : 100.00
# UNITS : [('sec', 220436L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 220436 )
#
# Impaired Skin Width #5
# CHART 224954 : 100.00
# UNITS : [('cm', 8561L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8561 )
#
# ABI Ankle BP L (Impella)
# CHART 224318 : 100.00
# UNITS : [('mmHg', 22L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 22 )
#
# Impaired Skin Width #9
# CHART 227614 : 100.00
# UNITS : [('cm', 1315L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1315 )
#
# PA Catheter Zero/Calibrate
# CHART 225358 : 100.00
# UNITS : [('', 5001L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 5001 )
#
# 18 Gauge placed in the field
# CHART 228099 : 100.00
# UNITS : [('', 78672L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 78672 )
#
# Differential-Neuts
# CHART 225643 : 99.97
# UNITS : [('%', 18936L), ('', 6L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 18942 )
#
# Intra Cranial Pressure Alarm - Low
# CHART 223768 : 100.00
# UNITS : [('mmHg', 4366L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 4366 )
#
# Respiratory Rate
# CHART 220210 : 100.00
# UNITS : [('insp/min', 2707573L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2707573 )
#
# Unable to assess psychological
# CHART 225070 : 100.00
# UNITS : [('', 20969L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 20969 )
#
# Total Peripheral Resistance Index (TPRI) (NICOM)
# CHART 228382 : 100.00
# UNITS : [('dynes*sec/cm5/m2', 175L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 175 )
#
# Minute Volume Alarm - Low
# CHART 220292 : 100.00
# UNITS : [('L/min', 453272L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 453272 )
#
# OxygenScore_ApacheIV
# CHART 227035 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Stroke Volume (SV NICOM)
# CHART 228374 : 100.00
# UNITS : [('mL/beat', 673L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 673 )
#
# Stroke Volume Variation (SVV NICOM)
# CHART 228376 : 100.00
# UNITS : [('', 676L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 676 )
#
# Impaired Skin Odor #1
# CHART 224564 : 100.00
# UNITS : [('', 126456L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 126456 )
#
# Change in Blood Color
# CHART 228188 : 100.00
# UNITS : [('', 390L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 390 )
#
# Tunneled (Hickman) Dressing Occlusive
# CHART 227359 : 100.00
# UNITS : [('', 3353L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3353 )
#
# HR_ApacheIV
# CHART 227018 : 100.00
# UNITS : [('bpm', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Peak Insp. Pressure
# CHART 224695 : 100.00
# UNITS : [('cmH2O', 451454L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 451454 )
#
# LDL measured
# CHART 227441 : 99.22
# UNITS : [('mg/dL', 127L), ('units', 1L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 128 )
#
# Inspired Gas Temp.
# CHART 223872 : 100.00
# UNITS : [('?C', 123007L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 123007 )
#
# SVV (Arterial)
# CHART 227546 : 100.00
# UNITS : [('%', 16747L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 16747 )
#
# Triple Introducer Line Tip Cultured
# CHART 225736 : 100.00
# UNITS : [('', 19L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 19 )
#
# PA Line cm Mark
# CHART 223773 : 100.00
# UNITS : [('cm', 23689L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 23689 )
#
# HrApacheIIScore
# CHART 226763 : 100.00
# UNITS : [('', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Orthostatic HR lying
# CHART 223764 : 100.00
# UNITS : [('bpm', 158L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 158 )
#
# Triglyceride
# CHART 225693 : 100.00
# UNITS : [('mg/dL', 2772L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2772 )
#
# Impella Catheter Position
# CHART 228162 : 100.00
# UNITS : [('cm', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# Unable to assess pain
# CHART 225112 : 100.00
# UNITS : [('', 12399L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 12399 )
#
# ARF
# CHART 226997 : 100.00
# UNITS : [('', 2L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2 )
#
# 22 Gauge Dressing Occlusive
# CHART 227369 : 100.00
# UNITS : [('', 40556L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 40556 )
#
# Respiratory Rate (Total)
# CHART 224690 : 100.00
# UNITS : [('insp/min', 397555L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 397555 )
#
# Impaired Skin Width #4
# CHART 224953 : 100.00
# UNITS : [('cm', 13308L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 13308 )
#
# Glucose finger stick
# CHART 225664 : 100.00
# UNITS : [('', 244297L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 244297 )
#
# Impaired Skin Length #3
# CHART 224917 : 100.00
# UNITS : [('cm', 21552L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 21552 )
#
# RRScore_ApacheIV
# CHART 227051 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# CreatinineApacheIIScore
# CHART 226751 : 100.00
# UNITS : [('', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Lipase
# CHART 225672 : 99.95
# UNITS : [('IU/L', 8383L), ('', 4L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8387 )
#
# Phenobarbital
# CHART 227460 : 100.00
# UNITS : [('ug/mL', 249L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 249 )
#
# ABI Brachial BP R
# CHART 228146 : 100.00
# UNITS : [('mmHg', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# AVA Line Zero/Calibrate
# CHART 227731 : 100.00
# UNITS : [('', 991L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 991 )
#
# PCA basal rate (mL/hour)
# CHART 224331 : 100.00
# UNITS : [('ml/hr', 13377L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 13377 )
#
# ART Blood Pressure Alarm - Low
# CHART 227538 : 100.00
# UNITS : [('mmHg', 5029L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 5029 )
#
# Venous CO2 Pressure
# CHART 226062 : 100.00
# UNITS : [('mmHg', 4102L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 4102 )
#
# PotassiumApacheIIValue
# CHART 226772 : 100.00
# UNITS : [('', 9L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9 )
#
# HtScore_ApacheIV
# CHART 227020 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# FiO2ApacheIIValue
# CHART 226754 : 100.00
# UNITS : [('%', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Sed Rate
# CHART 227470 : 100.00
# UNITS : [('mm/hr', 647L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 647 )
#
# ITBVI (PiCCO)
# CHART 228181 : 100.00
# UNITS : [('mL/m2', 1L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1 )
#
# Activity HR - Aerobic Capacity
# CHART 227864 : 100.00
# UNITS : [('', 289L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 289 )
#
# 22 Gauge placed in outside facility
# CHART 226139 : 100.00
# UNITS : [('', 40125L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 40125 )
#
# PEEP set
# CHART 220339 : 100.00
# UNITS : [('cmH2O', 477388L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 477388 )
#
# Rest RR - Aerobic Capacity
# CHART 227860 : 100.00
# UNITS : [('', 329L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 329 )
#
# CCO PAC Line Tip Cultured
# CHART 225723 : 100.00
# UNITS : [('', 417L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 417 )
#
# Sheath placed in outside facility
# CHART 226117 : 100.00
# UNITS : [('', 2263L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2263 )
#
# Lactic Acid
# CHART 225668 : 99.92
# UNITS : [('mmol/L', 63556L), ('', 49L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 63605 )
#
# Differential-Lymphs
# CHART 225641 : 99.97
# UNITS : [('%', 18936L), ('', 6L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 18942 )
#
# ScvO2 Central Venous O2% Sat
# CHART 226541 : 100.00
# UNITS : [('', 16L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 16 )
#
# Recovery RR - Aerobic Activity Response
# CHART 227932 : 100.00
# UNITS : [('', 93L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 93 )
#
# BIS Index Range
# CHART 228444 : 100.00
# UNITS : [('', 222L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 222 )
#
# Temporary Ventricular Sens Setting mV
# CHART 224837 : 100.00
# UNITS : [('mV', 6493L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6493 )
#
# Emotional / physical / sexual harm by partner or close relation
# CHART 225076 : 100.00
# UNITS : [('', 26551L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 26551 )
#
# Minute Volume
# CHART 224687 : 100.00
# UNITS : [('L/min', 447059L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 447059 )
#
# Impaired Skin Length #7
# CHART 224921 : 100.00
# UNITS : [('cm', 3816L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3816 )
#
# Pheresis Catheter Dressing Occlusive
# CHART 227362 : 100.00
# UNITS : [('', 1084L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1084 )
#
# ApacheIV_Mortality prediction
# CHART 226994 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Estimated Protein Needs/Kg
# CHART 226184 : 100.00
# UNITS : [('g/kg', 424L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 424 )
#
# Cerebral Perfusion Pressure
# CHART 227066 : 100.00
# UNITS : [('mmHg', 77621L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 77621 )
#
# Infusion Pressure of Line
# CHART 228191 : 100.00
# UNITS : [('', 665L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 665 )
#
# WBC_ApacheIV
# CHART 227062 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Vti High
# CHART 223874 : 100.00
# UNITS : [('mL', 446013L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 446013 )
#
# CO (Arterial)
# CHART 227543 : 100.00
# UNITS : [('L/min', 18604L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 18604 )
#
# Brain Natiuretic Peptide (BNP)
# CHART 227446 : 100.00
# UNITS : [('pg/mL', 1047L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1047 )
#
# Orthostatic BPs sitting
# CHART 224646 : 100.00
# UNITS : [('mmHg', 193L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 193 )
#
# Platelet Count
# CHART 227457 : 99.92
# UNITS : [('K/uL', 124728L), ('', 103L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 124831 )
#
# GEDI (PiCCO)
# CHART 228180 : 100.00
# UNITS : [('mL/m2', 1236L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1236 )
#
# PAR-Remain sedated
# CHART 228233 : 100.00
# UNITS : [('', 1137L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1137 )
#
# Aortic Pressure Signal - Systolic
# CHART 228152 : 100.00
# UNITS : [('', 30L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 30 )
#
# Assisted living
# CHART 225417 : 100.00
# UNITS : [('', 11L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 11 )
#
# Recovery HR - Aerobic Capacity
# CHART 227870 : 100.00
# UNITS : [('', 303L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 303 )
#
# Temporary AV interval
# CHART 220194 : 100.00
# UNITS : [('msec', 208L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 208 )
#
# PCA dose
# CHART 224328 : 100.00
# UNITS : [('', 22866L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 22866 )
#
# CK (CPK)
# CHART 225634 : 99.90
# UNITS : [('IU/L', 24019L), ('', 25L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 24044 )
#
# Vancomycin (Trough)
# CHART 227455 : 99.94
# UNITS : [('ug/mL', 6273L), ('', 4L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6277 )
#
# Ostomy Care
# CHART 225191 : 100.00
# UNITS : [('', 155L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 155 )
#
# Freeform Chemistry
# CHART 225656 : 100.00
# UNITS : [('', 2L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2 )
#
# Pheresis Catheter Line Tip Cultured
# CHART 225731 : 100.00
# UNITS : [('', 23L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 23 )
#
# CO2 production
# CHART 220245 : 100.00
# UNITS : [('ml/min', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# PCA lockout (min)
# CHART 224329 : 100.00
# UNITS : [('min', 22746L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 22746 )
#
# Chloride (whole blood)
# CHART 226536 : 99.63
# UNITS : [('mEq/L', 10695L), ('', 40L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10735 )
#
# Doppler BP
# CHART 224166 : 100.00
# UNITS : [('mmHg', 69L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 69 )
#
# APS
# CHART 226996 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Ejection Fraction
# CHART 227008 : 100.00
# UNITS : [('%', 2L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2 )
#
# Impella 2.5 Flow Rate
# CHART 228154 : 100.00
# UNITS : [('L/min', 31L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 31 )
#
# Heart Rate Alarm - Low
# CHART 220047 : 100.00
# UNITS : [('bpm', 209414L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 209414 )
#
# Recovery RR - Aerobic Capacity
# CHART 227872 : 100.00
# UNITS : [('', 244L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 244 )
#
# GcsApacheIIScore
# CHART 226755 : 100.00
# UNITS : [('', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Any fear in relationships
# CHART 225074 : 100.00
# UNITS : [('', 30425L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 30425 )
#
# Access Site Observed (Tandem Heart)
# CHART 228186 : 100.00
# UNITS : [('', 653L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 653 )
#
# CK-MB
# CHART 227445 : 99.96
# UNITS : [('ng/mL', 18652L), ('', 8L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 18660 )
#
# IABP Mean
# CHART 224322 : 100.00
# UNITS : [('mmHg', 8448L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8448 )
#
# PSV Level
# CHART 224701 : 100.00
# UNITS : [('cmH2O', 116780L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 116780 )
#
# Mixed Venous O2% Sat
# CHART 225674 : 100.00
# UNITS : [('%', 8929L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8929 )
#
# Discharge needs
# CHART 225133 : 100.00
# UNITS : [('', 17186L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 17186 )
#
# Impaired Skin Width #7
# CHART 224956 : 100.00
# UNITS : [('cm', 3816L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3816 )
#
# HDL
# CHART 220624 : 100.00
# UNITS : [('mg/dL', 1357L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1357 )
#
# Cardiac Output (CCO)
# CHART 224842 : 100.00
# UNITS : [('L/min', 61020L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 61020 )
#
# MapScore_ApacheIV
# CHART 227024 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Total Protein
# CHART 220650 : 99.86
# UNITS : [('g/dL', 729L), ('', 1L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 730 )
#
# Expiratory Ratio
# CHART 226871 : 100.00
# UNITS : [('', 205495L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 205495 )
#
# Cannulas Visible
# CHART 228187 : 100.00
# UNITS : [('', 657L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 657 )
#
# RIC placed in outside facility
# CHART 226140 : 100.00
# UNITS : [('', 482L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 482 )
#
# PH (dipstick)
# CHART 220734 : 99.84
# UNITS : [('units', 15823L), ('', 26L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 15849 )
#
# Midline Tip Cultured
# CHART 225728 : 100.00
# UNITS : [('', 170L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 170 )
#
# Tidal Volume (observed)
# ...
#
# Multi Lumen Line Tip Cultured
# CHART 225729 : 100.00
# UNITS : [('', 3708L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3708 )
#
# Hematocrit (whole blood - calc)
# CHART 226540 : 99.29
# UNITS : [('%', 15890L), ('', 114L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 16004 )
#
# Back Care
# CHART 225187 : 100.00
# UNITS : [('', 254877L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 254877 )
#
# Temporary Pacemaker Wires Atrial
# CHART 224839 : 100.00
# UNITS : [('', 24754L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 24754 )
#
# ICP Line placed in outside facility
# CHART 226129 : 100.00
# UNITS : [('', 8765L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8765 )
#
# Calcium non-ionized
# CHART 225625 : 99.74
# UNITS : [('mg/dL', 123052L), ('', 322L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 123374 )
#
# Tobramycin (Random)
# CHART 227451 : 100.00
# UNITS : [('ug/mL', 211L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 211 )
#
# CI (PiCCO)
# CHART 228177 : 100.00
# UNITS : [('L/min/m2', 2568L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2568 )
#
# SpO2 Desat Limit
# CHART 226253 : 100.00
# UNITS : [('%', 196863L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 196863 )
#
# Transpulmonary Pressure (Insp. Hold)
# CHART 224747 : 100.00
# UNITS : [('cmH2O', 420L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 420 )
#
# Impaired Skin Odor #7
# CHART 224928 : 100.00
# UNITS : [('', 7322L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7322 )
#
# Impaired Skin Depth #6
# CHART 224899 : 100.00
# UNITS : [('cm', 1847L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1847 )
#
# Estimated Energy Needs/Kg
# CHART 226183 : 100.00
# UNITS : [('kcal/kg', 454L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 454 )
#
# Sodium (serum)
# CHART 220645 : 99.84
# UNITS : [('mEq/L', 148699L), ('', 233L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 148932 )
#
# Arterial Line placed in outside facility
# CHART 226107 : 100.00
# UNITS : [('', 177091L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 177091 )
#
# Unable to assess nutrition / education
# CHART 225117 : 100.00
# UNITS : [('', 17947L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 17947 )
#
# ICP Line Tip Cultured
# CHART 226131 : 100.00
# UNITS : [('', 124L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 124 )
#
# Hospice home
# CHART 225420 : 100.00
# UNITS : [('', 12L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 12 )
#
# Respiratory Rate (spontaneous)
# CHART 224689 : 100.00
# UNITS : [('insp/min', 450737L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 450737 )
#
# Manual Blood Pressure Systolic Right
# CHART 227243 : 100.00
# UNITS : [('mmHg', 539L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 539 )
#
# Resp Alarm - High
# CHART 224161 : 100.00
# UNITS : [('insp/min', 205054L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 205054 )
#
# O2 Saturation Pulseoxymetry Alarm - Low
# CHART 223770 : 100.00
# UNITS : [('%', 206967L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 206967 )
#
# SV (Arterial)
# CHART 227547 : 100.00
# UNITS : [('mL/beat', 12716L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 12716 )
#
# Impaired Skin Width #8
# CHART 224957 : 100.00
# UNITS : [('cm', 2398L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2398 )
#
# Digoxin
# CHART 227440 : 99.92
# UNITS : [('ng/mL', 1224L), ('', 1L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1225 )
#
# Activity RR - Aerobic Activity Response
# CHART 227925 : 100.00
# UNITS : [('', 102L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 102 )
#
# Arterial Line Zero/Calibrate
# CHART 225210 : 100.00
# UNITS : [('', 76703L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 76703 )
#
# Tandem Heart Return Cannula Dressing Occlusive
# CHART 228219 : 100.00
# UNITS : [('', 130L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 130 )
#
# Presep Catheter placed in outside facility
# CHART 226116 : 100.00
# UNITS : [('', 2020L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2020 )
#
# Collar Care
# CHART 225192 : 100.00
# UNITS : [('', 5080L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 5080 )
#
# Central Venous Pressure
# CHART 220074 : 100.00
# UNITS : [('mmHg', 508766L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 508766 )
#
# Pin Care
# CHART 225190 : 100.00
# UNITS : [('', 392L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 392 )
#
# PHPaCO2Score_ApacheIV
# CHART 227038 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Return Site Observed (Tandem Heart)
# CHART 228196 : 100.00
# UNITS : [('', 653L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 653 )
#
# Procan Napa
# CHART 227459 : 100.00
# UNITS : [('ug/mL', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# 16 Gauge placed in the field
# CHART 228098 : 100.00
# UNITS : [('', 21942L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 21942 )
#
# Apache IV PaFiRatio
# CHART 226990 : 100.00
# UNITS : [('', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# Pulsus Paradoxus
# CHART 224192 : 100.00
# UNITS : [('', 309L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 309 )
#
# GlucoseScore_ApacheIV
# CHART 227016 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Recovery O2 Sat - Aerobic Capacity
# CHART 227873 : 100.00
# UNITS : [('%', 293L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 293 )
#
# Serum Osmolality
# CHART 225684 : 99.64
# UNITS : [('mOsm/kg', 6034L), ('', 22L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6056 )
#
# SOFA Score
# CHART 227428 : 100.00
# UNITS : [('', 2L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2 )
#
# Triple Introducer Zero/Calibrate
# CHART 225398 : 100.00
# UNITS : [('', 131L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 131 )
#
# Daily Weight
# CHART 224639 : 100.00
# UNITS : [('kg', 46201L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 46201 )
#
# GCS - Motor Response
# CHART 223901 : 100.00
# UNITS : [('', 562421L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 562421 )
#
# CK-MB fraction (%)
# CHART 225628 : 99.98
# UNITS : [('%', 5724L), ('', 1L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 5725 )
#
# 20 Gauge Dressing Occlusive
# CHART 227368 : 100.00
# UNITS : [('', 177524L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 177524 )
#
# PA Catheter Line Tip Cultured
# CHART 225730 : 100.00
# UNITS : [('', 440L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 440 )
#
# Spont Vt
# CHART 224421 : 100.00
# UNITS : [('mL', 16224L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 16224 )
#
# Manual Blood Pressure Diastolic Right
# CHART 227242 : 100.00
# UNITS : [('mmHg', 478L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 478 )
#
# Unable to assess activity / mobility
# CHART 225091 : 100.00
# UNITS : [('', 16409L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 16409 )
#
# Oxygenator Sweep Rate
# CHART 228192 : 100.00
# UNITS : [('L/min', 691L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 691 )
#
# 18 Gauge Dressing Occlusive
# CHART 227367 : 100.00
# UNITS : [('', 130697L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 130697 )
#
# Cuff Volume (mL)
# CHART 224418 : 100.00
# UNITS : [('mL', 2683L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2683 )
#
# Long term care custodial non-Medicare certified
# CHART 225416 : 100.00
# UNITS : [('', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Family Meeting
# CHART 224447 : 100.00
# UNITS : [('', 1633L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1633 )
#
# Phosphorous
# CHART 225677 : 99.95
# UNITS : [('mg/dL', 123547L), ('', 64L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 123611 )
#
# Central Venous Pressure  Alarm - Low
# CHART 220073 : 100.00
# UNITS : [('mmHg', 36168L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 36168 )
#
# Indwelling Port (PortaCath) Dressing Occlusive
# CHART 227360 : 100.00
# UNITS : [('', 8054L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8054 )
#
# Free care pharmacy
# CHART 225423 : 100.00
# UNITS : [('', 9L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9 )
#
# 14 Gauge Dressing Occlusive
# CHART 227365 : 100.00
# UNITS : [('', 3110L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3110 )
#
# Uric Acid
# CHART 225695 : 100.00
# UNITS : [('mg/dL', 1492L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1492 )
#
# Pulmonary Artery Pressure Alarm - Low
# CHART 220066 : 100.00
# UNITS : [('mmHg', 10584L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10584 )
#
# PCA 1 hour limit
# CHART 224330 : 100.00
# UNITS : [('', 22711L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 22711 )
#
# Vancomycin (Peak)
# CHART 227453 : 100.00
# UNITS : [('ug/mL', 12L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 12 )
#
# Inspiratory Ratio
# CHART 226873 : 100.00
# UNITS : [('', 205010L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 205010 )
#
# Intra Cranial Pressure Alarm - High
# CHART 223767 : 100.00
# UNITS : [('mmHg', 4294L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 4294 )
#
# Impaired Skin Width #2
# CHART 224951 : 100.00
# UNITS : [('cm', 30913L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 30913 )
#
# RRApacheIIValue
# CHART 226774 : 100.00
# UNITS : [('insp/min', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Potassium (serum)
# CHART 227442 : 99.92
# UNITS : [('mEq/L', 151198L), ('', 120L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 151318 )
#
# Called Out
# CHART 225280 : 100.00
# UNITS : [('', 7544L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7544 )
#
# Anion gap
# CHART 227073 : 99.96
# UNITS : [('mEq/L', 137258L), ('', 60L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 137318 )
#
# Potassium (whole blood)
# CHART 227464 : 99.86
# UNITS : [('mEq/L', 42532L), ('', 59L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 42591 )
#
# Glucose_ApacheIV
# CHART 227015 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Visual / hearing deficit
# CHART 225087 : 100.00
# UNITS : [('', 35777L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 35777 )
#
# Unable to assess habits
# CHART 225105 : 100.00
# UNITS : [('', 11628L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 11628 )
#
# Breast Feed - R (Minutes)
# CHART 227646 : 100.00
# UNITS : [('min', 9L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 9 )
#
# Patient agrees with the above goals and is willing to participate in the rehabilitation program
# CHART 227905 : 100.00
# UNITS : [('', 129L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 129 )
#
# Bed Bath
# CHART 225313 : 100.00
# UNITS : [('', 61329L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 61329 )
#
# Dialysis Catheter Dressing Occlusive
# CHART 227357 : 100.00
# UNITS : [('', 32779L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 32779 )
#
# Cerebral Perfusion Pressure Alarm - High
# CHART 227716 : 100.00
# UNITS : [('mmHg', 1967L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1967 )
#
# TemperatureF_ApacheIV
# CHART 227054 : 100.00
# UNITS : [('?F', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Orthostatic BPd standing
# CHART 226096 : 100.00
# UNITS : [('mmHg', 135L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 135 )
#
# Parameters Checked
# CHART 224168 : 100.00
# UNITS : [('', 500255L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 500255 )
#
# CCO PAC Dressing Occlusive
# CHART 227352 : 100.00
# UNITS : [('', 8734L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 8734 )
#
# Intra Cranial Pressure #2
# CHART 227989 : 100.00
# UNITS : [('mmHg', 1052L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1052 )
#
# Differential-Monos
# CHART 225642 : 99.97
# UNITS : [('%', 18936L), ('', 6L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 18942 )
#
# Impaired Skin Width #3
# CHART 224952 : 100.00
# UNITS : [('cm', 21080L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 21080 )
#
# Patient/family/team understand & agree with plan
# CHART 225424 : 100.00
# UNITS : [('', 20L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 20 )
#
# Smoking Cessation Info Offered through BIDMC Inpatient Guide
# CHART 227688 : 100.00
# UNITS : [('', 78170L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 78170 )
#
# Impaired Skin Odor #4
# CHART 224925 : 100.00
# UNITS : [('', 29198L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 29198 )
#
# RrApacheIIScore
# CHART 226773 : 100.00
# UNITS : [('', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# LOS pre-ICU admission
# CHART 227022 : 100.00
# UNITS : [('', 6L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 6 )
#
# Sheath Line Dressing Occlusive
# CHART 227356 : 100.00
# UNITS : [('', 2429L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2429 )
#
# IABP placed in outside facility
# CHART 226110 : 100.00
# UNITS : [('', 2077L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2077 )
#
# Dialysis Catheter Tip Cultured
# CHART 225725 : 100.00
# UNITS : [('', 676L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 676 )
#
# Right Ventricular Assist Device Flow
# CHART 220128 : 100.00
# UNITS : [('L/min', 632L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 632 )
#
# AgeApacheIIValue
# CHART 226739 : 100.00
# UNITS : [('years', 10L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10 )
#
# Incentive Spirometry
# CHART 225189 : 100.00
# UNITS : [('', 39227L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 39227 )
#
# Apnea Interval
# CHART 223876 : 100.00
# UNITS : [('sec', 452948L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 452948 )
#
# Medication Infusion Rate - Adjunctive Pain Management
# CHART 227812 : 100.00
# UNITS : [('', 1006L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1006 )
#
# Recruitment Duration
# CHART 224711 : 100.00
# UNITS : [('sec', 376L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 376 )
#
# Impaired Skin Odor #3
# CHART 224924 : 100.00
# UNITS : [('', 46029L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 46029 )
#
# Sexuality / reproductive problems
# CHART 226180 : 100.00
# UNITS : [('', 27117L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 27117 )
#
# SVRI (PiCCO)
# CHART 228185 : 100.00
# UNITS : [('dynes.sec.cm-5/m2', 1506L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1506 )
#
# Impaired Skin Length #4
# CHART 224918 : 100.00
# UNITS : [('cm', 13513L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 13513 )
#
# Pulmonary Artery Pressure Alarm - High
# CHART 220063 : 100.00
# UNITS : [('mmHg', 10680L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 10680 )
#
# Creatinine
# CHART 220615 : 99.92
# UNITS : [('mg/dL', 139289L), ('', 111L)](2)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 139400 )
#
# Blood Transfusion Consent
# CHART 226473 : 100.00
# UNITS : [('', 2757L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 2757 )
#
# AVA Line placed in outside facility
# CHART 227727 : 100.00
# UNITS : [('', 3134L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 3134 )
#
# ApacheIV_Natural antilog
# CHART 226995 : 100.00
# UNITS : [('', 7L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 7 )
#
# Freeform Coags
# CHART 225657 : 100.00
# UNITS : [('', 1L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1 )
#
# Tandem Heart Access Line Pump Housing Checked
# CHART 228212 : 100.00
# UNITS : [('', 100L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 100 )
#
# Impaired Skin Depth #9
# CHART 227596 : 100.00
# UNITS : [('cm', 553L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 553 )
#
# Vacuum Assist
# CHART 224659 : 100.00
# UNITS : [('mmHg', 626L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 626 )
#
# Arterial Line Tip Cultured
# CHART 225722 : 100.00
# UNITS : [('', 4507L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 4507 )
#
# P High (APRV)
# CHART 224705 : 100.00
# UNITS : [('cmH2O', 945L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 945 )
#
# Skin Care
# CHART 225185 : 100.00
# UNITS : [('', 252140L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 252140 )
#
# SVI (PiCCO)
# CHART 228182 : 100.00
# UNITS : [('mL/m2', 1926L)](1)
# Numeric observation :100.0000% ( NOTNUM= 0 / ALL= 1926 )

# %%
np.save('res/filtered_chart',{'id':valid_chart,'unit':valid_chart_unit});
np.save('res/filtered_chart_cate',{'id':[223758],'unit':None});
print "saved !";
# Out:
# saved !
